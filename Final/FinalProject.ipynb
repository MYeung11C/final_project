# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Finals.csv')

# %%
df
# Out:
#     OBJECTID_1  Join_Count  TARGET_FID  OBJECTID  STATEFP  STATENS  \
# 0            1           1           1         1       72  1779808
# 1            2           1           2         2       28  1779790
# 2            3           1           3         3        5    68085
# 3            4           1           4         4       54  1779805
# 4            5           1           5         5        1  1779775
# 5            6           1           6         6       21  1779786
# 6            7           1           7         7       22  1629543
# 7            8           1           8         8       35   897535
# 8            9           1           9         9       47  1325873
# 9           10           1          10        10       45  1779799
# 10          11           1          11        11       40  1102857
# 11          12           1          12        12       37  1027616
# 12          13           1          13        13       30   767982
# ...

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df  = pd.read_csv("finals.csv")
df.plot(kind='scatter',x='Median_Household Income',y='Stroke Mortality per 100K') # scatter plot
# Out:
# <AxesSubplot:xlabel='Median_Household Income', ylabel='Stroke Mortality per 100K'>

# %%
myMax = max(max(df['Median_Household Income']), max(df['Stroke Mortality per 100K']))
myMax
# Out:
# 76067

# %%
plt.scatter(df['Median_Household Income'], df['Stroke Mortality per 100K'])
plt.xlabel('Median_Household Income')
plt.ylabel('Stroke Mortality per 100K')
plt.plot([35000,myMax],[50,25])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Out:
# 'Median_household Income'
